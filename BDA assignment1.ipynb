# %%
s=input()
s=s[:-2] #this will remove frist 2 characters
print(s[::-1]) #[::-1] will reverse the string
# Out:
# python
# htyp

# %%
s1=input()
s1=s1.replace("python","pythons") # relaces python with pythons
print(s1)
# Out:
# i love python
# i love pythons

# %%
m=int(input())
if m>=90:
  g="A"
elif m>=80:
  g="B"
elif m>=70:
  g="C"
elif m>=60:
  g="D"
else:
  g="F"
print(g)
# Out:
# 85
# B

# %%
x=[23,"python",23.98]
print([type(y) for y in x]) # this is an alrternative us of for loop
# Out:
# [<class 'int'>, <class 'str'>, <class 'float'>]

# %%
IT = {'Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon'}
A = {19, 22, 24, 20, 25, 26}
B = {19, 22, 20, 25, 26, 24, 28, 27}
age = [22, 19, 24, 25, 26, 24, 25, 24]
print(len(IT))

IT.add("Twitter")
print(IT)

IT = IT | {'Tesla','Instagram'} # |is the union sign
print(IT)

IT.remove('Instagram') # remove keyword is used to remove items from set
print(IT)

# remove will give a keyword error if the item is not present in the set and discard doesnt give an error
# Out:
# 7
# {'Google', 'Microsoft', 'IBM', 'Twitter', 'Oracle', 'Amazon', 'Facebook', 'Apple'}
# {'IBM', 'Twitter', 'Tesla', 'Google', 'Microsoft', 'Oracle', 'Amazon', 'Instagram', 'Facebook', 'Apple'}
# {'IBM', 'Twitter', 'Tesla', 'Google', 'Microsoft', 'Oracle', 'Amazon', 'Facebook', 'Apple'}
# {19, 20, 22, 24, 25, 26, 27, 28}

# %%
C = A|B # | is union sign used to join sets we can also use .union() function...
print(C)
# Out:
# {19, 20, 22, 24, 25, 26, 27, 28}

# %%
D = A&B # & is for intersection we can also use .intersection() function
print(D)
# Out:
# {19, 20, 22, 24, 25, 26}

# %%
E = A.issubset(B)
print(E)
# Out:
# True

# %%
F = A.isdisjoint(B)
print(F)
# Out:
# False

# %%
G = A|B
H= B|A
print(G,H)
# Out:
# {19, 20, 22, 24, 25, 26, 27, 28} {19, 20, 22, 24, 25, 26, 27, 28}

# %%
I= A^B # this gives symmetric difference
print(I)
# Out:
# {27, 28}

# %%
del A,B  # del keyword is used to delete variables

# %%
print(A) #gives an error as the set A is deleted
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-25-212384544.py in <cell line: 0>()
# ----> 1 print(A)
#
# NameError: name 'A' is not defined

# %%
J=set(age)
print(J)

print(len(age) == len(J)) # set only takes unique values so the duplicates in age are eliminated...
# Out:
# {19, 22, 24, 25, 26}
# False

# %% [markdown]
# Thank you...
