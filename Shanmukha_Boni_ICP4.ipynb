# %% [markdown]
# <a href="https://colab.research.google.com/github/Shannu1922-ai/ICP/blob/main/Shanmukha_Boni_ICP4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data= {
    'ID' : np.arange(1,1000001),
    'Value': np.random.rand(1000000),
    'Category': np.random.choice(['A','B','C'],size=1000000)
}
df=pd.DataFrame(data)
df.head(10)
# Out:
#    ID     Value Category
# 0   1  0.454396        B
# 1   2  0.789961        C
# 2   3  0.663620        A
# 3   4  0.714547        B
# 4   5  0.316163        A
# 5   6  0.506171        C
# 6   7  0.141525        C
# 7   8  0.760431        C
# 8   9  0.636037        A
# 9  10  0.426324        A

# %%
df.Value
# Out:
# 0         0.454396
# 1         0.789961
# 2         0.663620
# 3         0.714547
# 4         0.316163
#             ...
# 999995    0.342818
# 999996    0.332997
# 999997    0.720380
# 999998    0.622431
# 999999    0.610591
# Name: Value, Length: 1000000, dtype: float64

# %%
df.columns = ['ID Number','Random Value','Choice']
df.head()
# Out:
#    ID Number  Random Value Choice
# 0          1      0.454396      B
# 1          2      0.789961      C
# 2          3      0.663620      A
# 3          4      0.714547      B
# 4          5      0.316163      A

# %%
pd.set_option('display.max_rows')

student_data = pd.DataFrame((
    'school code':['s001','s002','s003','s001','s002','s004'],
    'class':['V','V','VI','VI','V','VI
))

# %%
csv= pd.read_csv('data.csv')
csv.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
csv.fillna(csv.mean(),inplace=True)
csv.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
csv[['Duration','Pulse']].agg(['min','max','count','mean'])
# Out:
#          Duration       Pulse
# min     15.000000   80.000000
# max    300.000000  159.000000
# count  169.000000  169.000000
# mean    63.846154  107.461538

# %%
csv1 = csv[(csv['Calories']>500) & (csv['Calories']<1000)]
csv1.head()
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 51        80    123       146     643.1
# 62       160    109       135     853.0
# 65       180     90       130     800.4
# 66       150    105       135     873.4
# 67       150    107       130     816.0

# %%
csv1 = csv[(csv['Calories']>500) & (csv['Pulse']<100)]
csv1.head()
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 65       180     90       130     800.4
# 70       150     97       129    1115.0
# 73       150     97       127     953.2
# 75        90     98       125     563.2
# 99        90     93       124     604.1

# %%
df_modified = csv.drop(columns=['Maxpulse'])
df_modified.head()
# Out:
#    Duration  Pulse  Calories
# 0        60    110     409.1
# 1        60    117     479.0
# 2        60    103     340.0
# 3        45    109     282.4
# 4        45    117     406.0

# %%
csv.drop(columns=['Maxpulse'], inplace=True)
csv.head()
# Out:
#    Duration  Pulse  Calories
# 0        60    110     409.1
# 1        60    117     479.0
# 2        60    103     340.0
# 3        45    109     282.4
# 4        45    117     406.0

# %%
csv['Calories']=csv['Calories'].astype('int')
csv['Calories'].dtype
# Out:
# dtype('int64')

# %%
csv.plot.scatter(x='Duration', y='Calories')
# Out:
# <Axes: xlabel='Duration', ylabel='Calories'>
